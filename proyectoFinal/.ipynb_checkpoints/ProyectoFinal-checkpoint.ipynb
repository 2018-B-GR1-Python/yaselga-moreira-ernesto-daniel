# %%
import pandas as pd
import matplotlib.pyplot as plt
import codecs

# %% [markdown]
# # Preparación de datos sobre BitCoin

# %% [markdown]
# ## Carga de JSON con historial de datos de Bitcoin

# %%
df = pd.DataFrame
df = pd.read_json("/home/ernesteins/Documentos/python/yaselga-moreira-ernesto-daniel/proyectoFinal/BtcHw/recolectado/BtcRegistros.json")

# %%
plt.plot(df['date'],df['high'],
         df['date'],df['low'])
# Out:
# [<matplotlib.lines.Line2D at 0x7f5687205e10>,
#  <matplotlib.lines.Line2D at 0x7f5687426ac8>]

# %% [markdown]
# ## Limitamos el rango a los años 2017/01 - 2018/12

# %%
df20162018 = df[df['date'] <= '2019-01-01']
df20162018 = df20162018['2017-01-01' <= df20162018['date']]

# %%
plt.plot(df20162018['date'],df20162018['high'],
         df20162018['date'],df20162018['low'])
# Out:
# [<matplotlib.lines.Line2D at 0x7f568737e518>,
#  <matplotlib.lines.Line2D at 0x7f5687370f60>]

# %% [markdown]
# ## Limitamos el rngo a la épica más caótica del bit coin la cual fue entre Noviembre de 2017 y mayo de 2018

# %%
dfjunaug=df20162018[df20162018['date']<='2018-05-01']
dfjunaug=dfjunaug['2017-11-01' <= dfjunaug['date']]

# %%
plt.title("Histograma de precios del Bitcoin")
plt.plot(dfjunaug['date'],dfjunaug['high'],dfjunaug['date'],dfjunaug['low'])
plt.grid(True)
plt.text('2017-12-01', dfjunaug['high'].max(),"Precio más alto del bit-coin" )
plt.show()

# %% [markdown]
# # Preparación de Tweets

# %%
dfUsaAmd = pd.read_json('tweets_USA_amd.json')
dfUsaNvidia = pd.read_json('tweets_USA_nvidia.json')
#dfEcuadorAmd = pd.read_json('tweets_Ecuador_amd.json')
#dfEcuadorAmd = pd.read_json(codecs.open('tweets_ECUADOR_nvidia.json', 'r', 'utf-8'))
#dfEcuadorNvidia = pd.read_json('tweets_ECUADOR_nvidia.json')

# %%
cols = ['coordinates','text','lang']

# %%
df_usaA = dfUsaAmd[cols]
df_usaN = dfUsaNvidia[cols]

# %% [markdown]
# ## Filtrar tweets en ingles

# %%
df_usaN= df_usaN[df_usaN['lang'] == 'en']
df_usaA= df_usaA[df_usaA['lang'] == 'en']

# %% [markdown]
# ## Filtrar texto válido

# %%
def filtar_texto_valido(df):
    lista_indices = []
    import re
    patron_texto_valido = re.compile('^[a-zA-Z 0-9,.;#@\'\"&?$%()-+!]*$')
    for txt in df['text']:
        if patron_texto_valido.match(txt):
            lista_indices.append(True)
        else:
            lista_indices.append(False)
    return df[lista_indices]

# %%
df_usaN_text = filtar_texto_valido(df_usaN)
df_usaA_text = filtar_texto_valido(df_usaA)

# %%
df_usaN_text
df_usaA_text
# Out:
#      coordinates                                               text lang
# 11          None                                       Make it stop   en
# 14          None  @hannahsbirch @smartdissent @txtianmiller @Meg...   en
# 21          None  @TexansCap The degloving scene is the most ill...   en
# 25          None  @realDonaldTrump #TrailOfTears you and your so...   en
# 27          None                       $289,567 a month. Holy shit.   en
# 30          None    @mollycious420 I would eat you alive repeatedly   en
# 32          None                          dead ass tired of this bs   en
# 34          None              What is Tik Tok? Like a new age Vine?   en
# 44          None                 @shiratarlo @mollyhc She is a puke   en
# 56          None                            I so understand this!!!   en
# 60          None  @Lawrence What a wonderful compliment,you sure...   en
# 65          None                                    average at best   en
# 68          None                                     my weakness is   en
# 70          None  I trust President Trunp more than ALL of the l...   en
# 75          None  @DRH1959 Thank you for your service to this gr...   en
# 89          None                  Lately Da Baby Been Actin So Rude   en
# 93          None     We are in a relationship now.. So I can relate   en
# 96          None    @Megatron1133 Oh no. This is only the beginning   en
# 99          None  @NerdAboutTown Nobody in America is oppressed ...   en
# 101         None                        @ZerlinaMaxwell Interesting   en
# 102         None                  @okcthunder can i get a follow???   en
# 113         None                                      are you white   en
# 114         None          I need to put a cooler next to my bed lol   en
# 116         None  @torybruno @torybruno is it pretend or is that...   en
# 165         None                @AdamCopeland77 @CNN Yes absolutely   en
# 185         None                         @AnabelleLeigh1 I want you   en
# 189         None  @GCAthletics GREAT Picture showing the passion...   en
# 202         None                                I vaccinate my kids   en
# 211         None  then he tilted his head amd captured the young...   en
# 213         None                         Spit in her boodeeho hours   en
# ...          ...                                                ...  ...
# 1515        None  Do you ppl not undertand the point of standup ...   en
# 1518        None  Any thing or any person interrupting my peace ...   en
# 1524        None  @Rubaiin Ruben I'm legally obligated to dropki...   en
# 1525        None                           Get the Bitcoin for free   en
# 1527        None                     I can tell the difference now.   en
# 1544        None  Church is the greatest trick man ever played o...   en
# 1546        None     @wxnewsdesk No, your site is full of clickbait   en
# 1561        None                                               Amen   en
# 1572        None                             Your job sounds strict   en
# 1573        None            I second that. What is really going on?   en
# 1575        None                        @FUEGO562 Such a good movie   en
# 1576        None      Too hard a question this early in the morning   en
# 1578        None                      Fuck this shit wast worth it!   en
# 1579        None  Best part about being sick is crispy ass Sprit...   en
# 1581        None  @justplaintall @bopinion Puerile slurs are not...   en
# 1586        None                                 Manfuckthattypo!!!   en
# 1593        None                          @Naomiott Meat chocolate?   en
# 1601        None  Thank you @kirkwoodtrack! A great moment in Pi...   en
# 1603        None  @kbchoops is the place to be today.... #Champi...   en
# 1615        None  $XLM bids filled...now will it be a bounce or ...   en
# 1624        None   @htxtricia yes but we talking about the dog here   en
# 1631        None        Truth.  Thank you for reminding me of this!   en
# 1633        None  @CiearraTheQueen The truth is we want to be lo...   en
# 1641        None  Does it get any better than waking up on a Sun...   en
# 1642        None            fuck no i was cross faded af last night   en
# 1654        None                                   Be a good human.   en
# 1682        None                                   @SwayRoseo dm me   en
# 1687        None  @drboycewatkins1 The stupidity of this stands ...   en
# 1696        None  @bakermayfield You go boy! Let Go &amp; Let Go...   en
# 1702        None                Something about corrupt prosecutors   en
#
# [277 rows x 3 columns]

# %% [markdown]
# ## Análisis de sentimientos

# %%
import textblob
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-16-324dd8396cbd> in <module>
# ----> 1 import textblob
#
# ModuleNotFoundError: No module named 'textblob'

# %%
def analizar_texto(df):
    df_nuevo = pd.DataFrame(columns=['texto','sentimiento'])
    for txt in df['text']:
        txt_tweet = textblob.TextBlob(txt)
        resultado = ''
        if txt_tweet.sentiment.polarity > 0:
            resultado = 'positive'
        elif txt_tweet.sentiment.polarity <0:
            resultado = 'negative'
        else:
            resultado = 'neutral'
        row = [txt,resultado]
        df_nuevo.loc[len(df_nuevo)] = row
    return df_nuevo

# %%
df_analalizado = analizar_texto(df_usaN_text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-dbda03352ad6> in <module>
# ----> 1 df_analalizado = analizar_texto(df_usaN_text)
#
# <ipython-input-19-19578189e512> in analizar_texto(df)
#       2     df_nuevo = pd.DataFrame(columns=['texto','sentimiento'])
#       3     for txt in df['text']:
# ----> 4         txt_tweet = textblob.TextBlob(txt)
#       5         resultado = ''
#       6         if txt_tweet.sentiment.polarity > 0:
#
# NameError: name 'textblob' is not defined
